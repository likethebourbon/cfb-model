# %%
import pathlib

# %%
pathlib.Path('Untitled.py')
# Out:
# PosixPath('Untitled.py')

# %%
pathlib.Path.cwd()
# Out:
# PosixPath('/Users/evan/GitHub/cfb-model/notebooks')

# %%
import pandas as pd

# %%
pd.read_csv('../data/raw/pbp/2018 Week 1.csv', encoding='ISO-8859-1')
# Out:
#                        id             offense offense_conference  \
# 0      401012246101877401             Alabama                SEC
# 1      401012246101857401             Alabama                SEC
# 2      401012246101858901             Alabama                SEC
# 3      401012246101849902          Louisville                ACC
# 4      401012246101867401             Alabama                SEC
# 5      401012246101884401             Alabama                SEC
# 6      401012246101874901             Alabama                SEC
# 7      401012246101864901             Alabama                SEC
# 8      401012246101887901          Louisville                ACC
# 9      401012246101884404             Alabama                SEC
# 10     401012246101885301          Louisville                ACC
# 11     401012246101894401          Louisville                ACC
# 12     401012246101898901          Louisville                ACC
# ...
